# %%
import pandas as pd  
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_25848\2080173014.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
#Use the jupyter file from the previous lab on Customer Analysis

# %%
file = pd.read_csv("Data/marketing_customer_analysis.csv")
file.head(1)
# Out:
#   Customer       State  Customer Lifetime Value Response Coverage Education  \
# 0  BU79786  Washington              2763.519279       No    Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
#
#   Total Claim Amount Vehicle Class Vehicle Size
# 0         384.811147  Two-Door Car      Medsize
#
# [1 rows x 24 columns]

# %%
#Check the data types of the columns. Get the numeric data into dataframe called `numerical` and categorical columns in a 
#dataframe called `categoricals`. (You can use np.number and np.object to select the numerical data types and categorical data types respectively)

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
numerical = file.select_dtypes(np.number)
numerical.head()
# Out:
#    Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    Number of Open Complaints  Number of Policies  Total Claim Amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %%
categoricals = file.select_dtypes(np.object_)
categoricals.head()
# Out:
#   Customer       State Response  Coverage Education Effective To Date  \
# 0  BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1  QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2  AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3  WW63253  California       No     Basic  Bachelor           1/20/11
# 4  HB64268  Washington       No     Basic  Bachelor            2/3/11
#
#   EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# ...

# %%
#Use Matplotlib to construct histograms to check the normality of the numerical variables visually

# %%
for columns in numerical.columns:
    sns.distplot(numerical[columns])
    plt.show()
# Out:
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_25848\991322178.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical[columns])
# C:\Users\Usuario_1\AppData\Local\Temp\ipykernel_25848\991322178.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#Check the multicollinearity between the features. Please note that we will use the column `total_claim_amount` later as the target variable.

# %%
fig, ax=plt.subplots(figsize=(15,10))
ax=sns.heatmap(numerical.corr(), annot=True)
plt.show()

# %%
#Drop one of the two features that show a high correlation between them (greater than 0.9). 
#Write code for both the correlation matrix and for seaborn heatmap. 
#If there is no pair of features that have a high correlation, then do not drop any features

# %%
#- Split data into Y (`total_claim_amount`) and X (numerical, independent variables)

# %%
Y = numerical['Total Claim Amount']
X = numerical.drop(['Total Claim Amount'], axis=1)

# %%
#Conduct Linear Regressions
#Using Statsmodels

# %%
import numpy as np
from scipy.stats import norm
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     Total Claim Amount   R-squared:                       0.519
# Model:                            OLS   Adj. R-squared:                  0.518
# Method:                 Least Squares   F-statistic:                     1405.
# Date:                Thu, 25 Apr 2024   Prob (F-statistic):               0.00
# Time:                        19:25:15   Log-Likelihood:                -61425.
# No. Observations:                9134   AIC:                         1.229e+05
# Df Residuals:                    9126   BIC:                         1.229e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                            72.3910      8.744      8.279      0.000      55.252      89.530
# ...

# %%
# El modelo es 'decente' ya que R-Squared es mayor que 0.5, pero mejorable ya que es de 0,519
# Casi todos las variables son altamente significativas menos Number of Policies y Number of Open Complaints ya que tienen pval > 0,5.
# La variable de Monthly Premium Auto es muchisimo mas alto que el del resto de variables independientes, por lo que es la mas significativa.
# La interpretación del coeficiente es cuánto se movería la variable dependiente si la variable independiente sube en una unidad, manteniendo todo lo demás constante.

# %%
#Using sklearn

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

Y = numerical['Total Claim Amount']
X = numerical.drop(['Total Claim Amount'], axis=1)
lm = linear_model.LinearRegression()
model = lm.fit(X,Y)
print("R2 value is = ",round(lm.score(X,Y),2))
# Out:
# R2 value is =  0.52

# %%
predictions = lm.predict(X)
print("R2 value is = ",round(r2_score(Y, predictions),2))
print("The intercept of the model is = ",lm.intercept_)
print("The coefficients of the model are = ",lm.coef_)
predictions = lm.predict(X)
mse = mean_squared_error(Y, predictions)
print("The mse of the model is = ",mse)
# Out:
# R2 value is =  0.52
# The intercept of the model is =  72.39096819184186
# The coefficients of the model are =  [-6.74723453e-04 -3.29341526e-03  5.34254540e+00 -1.45721018e-01
#  -1.02321926e-01 -1.37160695e+00  2.48565252e-01]
# The mse of the model is =  40615.74326224916

# %%
# Mismo r2 value por lo que la conclusion es la misma.
# A nivel de coeficientes vemos los mismos resultados que en statmodels.
# Sin embargo, el MSE de este modelo es muy alto lo que nos dice que tiene una probabilidad de error muy alta. Lo cual es importante minimizar.
